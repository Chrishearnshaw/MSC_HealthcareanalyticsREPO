# %% [markdown]
# # Colab Auto Connect Demo
#
# Use this notebook to test `Kernel > Colab > Auto Connect`.
#
# Once connected, run each cell from top to bottom.

# %%
import sys
from datetime import datetime, timezone

print("Python:", sys.version.split()[0])
print("Notebook connected at:", datetime.now(timezone.utc).isoformat())
# Out:
# Python: 3.11.9
# Notebook connected at: 2026-07-02T14:10:41.409102+00:00

# %%
scores = [4, 7, 6, 9, 8]
labels = ["Mon", "Tue", "Wed", "Thu", "Fri"]

for label, score in zip(labels, scores):
    print(f"{label}: {score}")

print("Average score:", sum(scores) / len(scores))
# Out:
# Mon: 4
# Tue: 7
# Wed: 6
# Thu: 9
# Fri: 8
# Average score: 6.8

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 3.5))
plt.plot(labels, scores, marker="o", linewidth=2)
plt.title("Demo Scores")
plt.xlabel("Day")
plt.ylabel("Score")
plt.grid(True, alpha=0.3)
plt.show()

# %%
from pathlib import Path

output = Path("demo-output.txt")
output.write_text("The Colab demo notebook ran successfully.\n", encoding="utf-8")
print(f"Wrote {output.resolve()}")
# Out:
# Wrote C:\Users\chris\OneDrive\Documents\GitHub\2493-squadron-website\demo-output.txt
