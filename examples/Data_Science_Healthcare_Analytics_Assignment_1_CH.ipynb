# %% [markdown]
# # Assignment 1 — Exploratory Analysis of Hospital Claims

# %% [markdown]
# ##Overview
#
# You have been given a de-identified extract of 2020 hospital claims data. Working as a junior analyst on a payer's analytics team, you will load the data, clean and derive fields, answer descriptive questions, produce three visualizations, and enrich the claims with member enrollment information. The tasks mirror the everyday workflow of a healthcare data analyst and build directly on the pandas and seaborn material from Weeks 1–6.
#
# All work must be done in Python using pandas and seaborn. Show your code and its output for every question. Where a question asks for interpretation, add a short written explanation (2–4 sentences).
#
# Two ways to submit. You may complete this assignment as a traditional Jupyter notebook or by working through the tasks in a Claude session and submitting that conversation. Using an AI assistant such as Claude is explicitly permitted. Whichever route you choose, you are responsible for the analysis: directing the work part by part, verifying the outputs, and explaining the results in your own words. Full details are in the Submission Requirements section below.
#
# Datasets
#
# HealthcareDataset_PublicRelease.csv — one row per claim line item (52,563 rows, 17 columns). Key fields:
#
# • MemberID, County — de-identified patient and geography (hashed)
#
# • MedicalClaim, ClaimItem — a claim groups multiple line items
#
# • HospitalName, HospitalType — HOSPITAL / HOSPITAL LONG TERM ACUTE / REHABILITATION CENTER
#
# • StartDate, EndDate, BirthDate — service and birth dates (parse as datetimes)
#
# • PrincipalDiagnosisDesc, PrincipalDiagnosis — description and ICD-10 code
#
# • RevenueCodeDesc, RevenueCode — billing revenue category
#
# • TypeFlag — INP (inpatient) or ER (emergency)
#
# • TotalExpenses — cost of the line item in USD
#
# MemberReference.csv — one row per member (1,757 rows): MemberID, PlanType (Bronze/Silver/Gold/Platinum), EnrollmentYear. Used in Part F. Load it directly from its source URL:

# %% [markdown]
# ### Part A — Load & Inspect (10 pts)
#
# 1. Load the dataset and report its shape (rows × columns).
#
# 2. Display the column names and their data types. Identify which columns holding dates are currently stored as text.
#
# 3. Report the number of missing values per column and state which column(s) are affected.
#
# 4. Print summary statistics for TotalExpenses and describe its distribution in one sentence (mean vs. median

# %% [markdown]
# ## Part A-1. Load the dataset and report its shape (rows × columns).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy import stats

# %%
member_url = ('https://raw.githubusercontent.com/thousandoaks/' 'Python4DS-I/refs/heads/main/datasets/MemberReference.csv') member_ref = pd.read_csv(member_url)

# %%
url = ('https://github.com/thousandoaks/Python4DS-I/' 'raw/main/datasets/HealthcareDataset_PublicRelease.csv') df = pd.read_csv(url)

# %%
happinessReport.head()

# %%
happinessReport.describe()

# %%
# Let's select 4 countries

countryFilter=['Mexico','Sweden','China','Afghanistan','Spain']

# %%
happinessReportFiltered=happinessReport[happinessReport['Country name'].isin(countryFilter)]

# %% [markdown]
# ### 1. Correlation matrix

# %% [markdown]
# #### Pandas provides a convenient method to compute the correlation matrix

# %%
happinessReportFiltered.columns

# %%
happinessReportFiltered[['Life Ladder','Log GDP per capita','Healthy life expectancy at birth']].corr()

# %% [markdown]
# ### 2. Heatmaps
#
# #### Seaborn provides a convenient method to compute the correlation matrix

# %%
correlationMatrix=happinessReportFiltered[['Freedom to make life choices','Life Ladder','Log GDP per capita','Healthy life expectancy at birth','Perceptions of corruption','Positive affect']].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlationMatrix, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlationMatrix, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},annot=True)

# %% [markdown]
# ### 3. Scatter Plots
# #### Scatter plots are incredibly useful!

# %% [markdown]
# #### There are several alternatives to compute scatter plots in Python:
#
# #### 1. Using Pandas
# #### 2. Using seaborn

# %%
happinessReportFiltered.plot(x='Log GDP per capita',    y='Healthy life expectancy at birth',    kind='scatter')

# %%
happinessReportFiltered.plot(x='Log GDP per capita',    y='Perceptions of corruption',    kind='scatter')

# %% [markdown]
# ### 4. Box Plots
# #### Box Plots are quite useful to summarize visually the distribution of a variable

# %% [markdown]
# #### We recommend using seaborn

# %%
sns.boxplot(data=happinessReportFiltered, x="Country name", y="Log GDP per capita")

# %%
sns.boxplot(data=happinessReportFiltered, x="Country name", y="Healthy life expectancy at birth")

# %%
sns.boxplot(data=happinessReportFiltered, x="Country name", y="Social support")

# %% [markdown]
# ### 5. Violin Plots
# #### Violin plots are also quite useful to summarize visually the distribution of a variable. They are more informative than boxplots.

# %%
sns.violinplot(data=happinessReportFiltered, x="Country name", y="Log GDP per capita")

# %%
sns.violinplot(data=happinessReportFiltered, x="Country name", y="Healthy life expectancy at birth")

# %%
sns.violinplot(data=happinessReportFiltered, x="Country name", y="Social support")
